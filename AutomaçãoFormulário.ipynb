# %% [markdown]
# # 🤖 Automação de Formulário Web com PyAutoGUI
#
# Este projeto preenche automaticamente um formulário online com os dados de um arquivo `produtos.csv`, usando `pyautogui` e `pandas`.
#
# ## 🚀 Funcionalidades
#
# - Abre o navegador e acessa um site de login
# - Preenche os campos de email e senha
# - Lê produtos de um arquivo CSV
# - Preenche os campos do formulário com base na planilha
# - Envia os dados e repete para todos os produtos
#
# ## 💡 Tecnologias Utilizadas
#
# - Python 3
# - PyAutoGUI
# - Pandas
# - time
#
# ## ⚙️ Como usar
#
# 1. Verifique se o arquivo `produtos.csv` está no mesmo diretório;
# 2. Execute o script com `python script.py`;
# 3. O sistema será preenchido automaticamente no navegador.
#
# ## 📘 Principais Comandos e Funções
#
# | Comando                          | Função e Tradução                                                                 |
# |----------------------------------|------------------------------------------------------------------------------------|
# | `pyautogui.press('tecla')`       | Pressiona uma tecla do teclado                                                    |
# | `pyautogui.write('texto')`       | Digita um texto como se fosse uma pessoa                                          |
# | `pyautogui.hotkey('ctrl', 'a')`  | Pressiona atalhos de teclado (CTRL+A para selecionar tudo)                        |
# | `pyautogui.click(x, y)`          | Move o mouse até (x, y) e clica                                                    |
# | `pyautogui.scroll(valor)`        | Rola a tela para cima ou baixo                                                    |
# | `time.sleep(segundos)`           | Espera o tempo definido antes de continuar                                        |
# | `pd.read_csv('arquivo.csv')`     | Lê um arquivo CSV usando o pandas                                                 |
# | `tabela.loc[linha, 'coluna']`    | Acessa o valor em uma linha e coluna específica da tabela                         |
# | `for linha in tabela.index:`     | Loop para executar uma ação em todas as linhas da planilha                        |
# | `str()`                          | Converte valores numéricos para string                                            |
#
# ---
#
# 🧑‍💻 Desenvolvido por **Rogério (rogeriothelast)**
# 📍 São Paulo - SP | 🌐 Apaixonado por automações e soluções inteligentes
# 📫 E-mail: rogeriothelast@gmail.com
# 📱 WhatsApp: (11) 95215-0048
# 🔗 GitHub: [github.com/Rogeriosil](https://github.com/Rogeriosil)

# %%
import pyautogui
import time

pyautogui.PAUSE = 3

pyautogui.press('win')
pyautogui.write('chrome')
pyautogui.press('enter')

pyautogui.write('https://dlp.hashtagtreinamentos.com/python/intensivao/login')
pyautogui.press('enter')

time.sleep(3)

pyautogui.click(x=685, y=474)
pyautogui.hotkey('ctrl', 'a')
pyautogui.write('rogeriothelast@gmail.com')

pyautogui.press('tab')
pyautogui.write('minha senha')

pyautogui.click(x=957, y=672)

time.sleep(3)

import pandas as pd

tabela = pd.read_csv('produtos.csv')

print(tabela)

for linha in tabela.index:
    
    pyautogui.click(x=609, y=325)
    codigo = str(tabela.loc[linha, 'codigo'])
    pyautogui.write(codigo)
    
    marca = str(tabela.loc[linha, 'marca'])
    pyautogui.press('tab')
    pyautogui.write(marca)
    
    tipo = str(tabela.loc[linha, 'tipo'])
    pyautogui.press('tab')
    pyautogui.write(tipo)
    
    categoria = str(tabela.loc[linha, 'categoria'])
    pyautogui.press('tab')
    pyautogui.write(categoria)
    
    preco = str(tabela.loc[linha, 'preco_unitario'])
    pyautogui.press('tab')
    pyautogui.write(preco)
    
    custo = str(tabela.loc[linha, 'custo'])
    pyautogui.press('tab')
    pyautogui.write(custo)
    
    pyautogui.press('tab')
    obs = str(tabela.loc[linha, 'obs']) 
    if  obs != 'nan':
        pyautogui.write(obs)
        
        pyautogui.press('tab')
        pyautogui.press('enter')
        
        
    pyautogui.click(x=849, y=686)   
    
    pyautogui.scroll(5000)
